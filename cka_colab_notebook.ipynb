# %%
# !nvidia-smi
import torch
print(f'CUDA: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'Memory: {torch.cuda.get_device_properties(0).total_memory/1e9:.1f} GB')
# Out:
# Tue Apr  7 17:21:48 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX PRO 6000 Blac...    Off |   00000000:05:00.0 Off |                    0 |
# | N/A   26C    P0             45W /  600W |       0MiB /  97887MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
shutil.copy2('/content/drive/My Drive/pe_experiment/full_scale_experiment.py', '/content/')
shutil.copy2('/content/drive/My Drive/pe_experiment/cka_orthogonality_trap.py', '/content/')
shutil.copy2('/content/drive/My Drive/pe_experiment/00_setup_imagenet.py', '/content/')
# Out:
# '/content/00_setup_imagenet.py'

# %%
# !python /content/00_setup_imagenet.py
# Out:
# ...
# ImageNet-100 Setup
# ...
#  Found: ILSVRC2012_img_val.tar
#  Found: imagenet100_classes.txt
#  Found: val_labels.txt
#
# ImageNet-100 classes: 100
# Val labels loaded: 50000 entries
# Output directory: /content/imagenet100/val
# Created 100 class folders
#
# Extracting from: /content/drive/My Drive/pe_experiment/imagenet/ILSVRC2012_img_val.tar
# (This may take 5-10 minutes depending on Drive speed...)
#
# Total images in tar: 50,000
# Filtering: 100% 50000/50000 [00:01<00:00, 26336.57img/s]
#
# ...
# Extraction complete!
#   Images extracted: 5,000
#   Images skipped:   45,000
#   Expected:         5,000
#
#  All 5,000 images extracted successfully.
#
# Per-class image count (first 5):
#   n01558993: 50 images
#   n01692333: 50 images
#   n01729322: 50 images
#   n01735189: 50 images
#   n01749939: 50 images
#
#   Min images per class: 50
#   Max images per class: 50
# All classes have exactly 50 images.
#
# Dataset ready at: /content/imagenet100/val

# %%
# !cp "/content/drive/My Drive/pe_experiment/cka_orthogonality_trap.py" /content/
# !rm -rf /content/cka_bar_imagenet100.pdf /content/cka_heatmaps_imagenet100.pdf
# !python /content/cka_orthogonality_trap.py
# Out:
# ...
# CKA Analysis for Orthogonality Trap Validation
# Dataset: imagenet100 | Device: cuda
# Images: 2000 | Seeds: [42, 123, 456]
# ...
#
# [1/4] Loading validation data...
#   Loaded 2000 images
#
# ...
# [2/4] Processing: SINUSOIDAL
# ...
#
#   --- Seed 42 ---
# Loading /content/drive/My Drive/pe_experiment/results/sinusoidal_seed42/best_model.pth
#   Extracting activations...
#   Processed 640 images
#   Processed 1280 images
#   Processed 1920 images
#   Layer 1: torch.Size([392000, 768])
#   Layer 2: torch.Size([392000, 768])
#   Layer 3: torch.Size([392000, 768])
#   Layer 4: torch.Size([392000, 768])
#   Layer 5: torch.Size([392000, 768])
#   Layer 6: torch.Size([392000, 768])
#   Layer 7: torch.Size([392000, 768])
#   Layer 8: torch.Size([392000, 768])
#   Layer 9: torch.Size([392000, 768])
#   Layer 10: torch.Size([392000, 768])
#   Layer 11: torch.Size([392000, 768])
#   Layer 12: torch.Size([392000, 768])
#   Computing key CKA pairs...
#     CKA(L1-L6) = 0.9926
#     CKA(L1-L12) = 0.9766
# ...
